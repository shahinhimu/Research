# %% [markdown]
# <a href="https://colab.research.google.com/github/shahinhimu/Research/blob/main/Assignment_4_Matplotlib_and_Seaborn_for_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required packages (run this first in Google Colab)
# !pip install numpy pandas matplotlib seaborn

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gym_membership= pd.read_csv('/content/drive/MyDrive/datasets/gym_membership.csv')  # No header in raw CSV

# %%
# Display last 5 rows
gym_membership.tail()
# Out:
#        id  gender    birthday  Age abonoment_type  visit_per_week  \
# 995   996  Female   9/22/1984   40       Standard               3
# 996   997  Female  11/19/2008   15       Standard               3
# 997   998    Male   10/5/1984   40       Standard               2
# 998   999    Male   2/22/2001   23       Standard               4
# 999  1000  Female    5/7/2006   18        Premium               2
#
#           days_per_week  attend_group_lesson fav_group_lesson  \
# 995       Thu, Tue, Wed                False              NaN
# 996       Fri, Mon, Sun                 True     XCore, Zumba
# 997            Fri, Tue                False              NaN
# 998  Mon, Sun, Thu, Tue                 True       HIT, XCore
# 999            Thu, Tue                False              NaN
#
#     avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 995          20:56:00           22:42:00              106      False
# ...

# %%
# Check data types
gym_membership.dtypes
# Out:
# id                        int64
# gender                   object
# birthday                 object
# Age                       int64
# abonoment_type           object
# visit_per_week            int64
# days_per_week            object
# attend_group_lesson        bool
# fav_group_lesson         object
# avg_time_check_in        object
# avg_time_check_out       object
# avg_time_in_gym           int64
# drink_abo                  bool
# fav_drink                object
# personal_training          bool
# name_personal_trainer    object
# uses_sauna                 bool
# dtype: object

# %%
# Task 1: Basic Matplotlib (3 plots)
# 1. Bar chart of gym membership types
# Use: gym['abonoment_type'].value_counts()

membership_counts = gym_membership['abonoment_type'].value_counts()
plt.figure(figsize=(8, 6))
plt.bar(membership_counts.index, membership_counts.values)
plt.title('Distribution of Gym Membership Types')
plt.xlabel('Membership Type')
plt.ylabel('Count')
plt.show()

# %%
# 2. Histogram of time in gym
# Use: plt.hist(gym['avg_time_in_gym'])

plt.figure(figsize=(8, 6))
plt.hist(gym_membership['avg_time_in_gym'], bins=20) # You can adjust the number of bins
plt.title('Distribution of Average Time in Gym')
plt.xlabel('Average Time in Gym (minutes)')
plt.ylabel('Frequency')
plt.show()

# %%
# 3. Scatter plot: Age vs visits per week
# Use: plt.scatter(gym['Age'], gym['visit_per_week'])

plt.figure(figsize=(8, 6))
plt.scatter(gym_membership['Age'], gym_membership['visit_per_week'])
plt.title('Age vs. Visits per Week')
plt.xlabel('Age')
plt.ylabel('Visits per Week')
plt.show()

# %%
# 1. Box plot: Gender vs Age
# Use: sns.boxplot(data=gym, x='gender', y='Age')

plt.figure(figsize=(8, 6))
sns.boxplot(data=gym_membership, x='gender', y='Age')
plt.title('Age Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()

# %%
# 2. Count plot: Days per week
# Use: sns.countplot(data=gym, x='days_per_week')

plt.figure(figsize=(40, 15))
sns.countplot(data=gym_membership, x='days_per_week', order=gym_membership['days_per_week'].value_counts().index)
plt.title('Distribution of Days per Week Attended')
plt.xlabel('Days per Week')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels overlapping
plt.show()

# %%
# 3. Bar plot: Average visits by membership type
# Use: sns.barplot(data=gym, x='abonoment_type', y='visit_per_week')

plt.figure(figsize=(8, 6))
sns.barplot(data=gym_membership, x='abonoment_type', y='visit_per_week')
plt.title('Average Visits per Week by Membership Type')
plt.xlabel('Membership Type')
plt.ylabel('Average Visits per Week')
plt.show()
